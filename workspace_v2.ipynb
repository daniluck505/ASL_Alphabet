# %% [markdown]
# # ASL Alphabet

# %%
# !git clone https://github.com/daniluck505/ASL_Alphabet.git
# Out:
# Cloning into 'ASL_Alphabet'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 32 (delta 7), reused 25 (delta 3), pack-reused 0
# Receiving objects: 100% (32/32), 15.77 KiB | 5.26 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !python /content/ASL_Alphabet/src/main.py
# Out:
# ...
# asl-alphabet.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  asl-alphabet.zip
# replace asl_alphabet_test/asl_alphabet_test/A_test.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: /usr/local/lib/python3.10/dist-packages/torch/nn/init.py:405: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# A:3000 | B:3000 | C:3000 | D:3000 | E:3000 | F:3000 | G:3000 | H:3000 | I:3000 | J:3000 | K:3000 | L:3000 | M:3000 | N:3000 | O:3000 | P:3000 | Q:3000 | R:3000 | S:3000 | T:3000 | U:3000 | V:3000 | W:3000 | X:3000 | Y:3000 | Z:3000 | del:3000 | nothing:3000 | space:3000 | 2816
#   0% 0/5437 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/ASL_Alphabet/src/main.py", line 151, in <module>
#     main()
#   File "/content/ASL_Alphabet/src/main.py", line 47, in main
# ...
